# %%
import google.generativeai as genai

# Configure API key
genai.configure(api_key="zzzzzzzzzzzzzzzzzzzzzzzz")  # Replace with your actual Gemini API key

# Initialize conversation
system_msg = input("What type of chatbot would you like to create?\n")

print("Your new assistant is ready!")

# Load the model
model = genai.GenerativeModel(model_name="gemini-2.5-flash")

# Start chatbot loop
while True:
    user_input = input()
    if user_input.lower() == "quit":
        break

    # Send user input directly (Gemini does not use "role")
    response = model.generate_content(user_input)

    # Extract response
    reply = response.text

    print("\n" + reply + "\n")
# Out:
# Your new assistant is ready!
#
# Both broccoli and eggs are incredibly healthy and offer distinct nutritional benefits, so neither is definitively "better" than the other. They simply provide different things your body needs.
#
# Here's a breakdown to help you decide which might be "better" for your specific needs, or why combining them is often the best approach:
#
# ### Broccoli: The Green Powerhouse
#
# **Strengths:**
# *   **Fiber:** Excellent source of dietary fiber, crucial for digestive health, preventing constipation, and helping you feel full.
# *   **Vitamins:** Packed with Vitamin C (for immunity and skin health), Vitamin K (for bone health and blood clotting), and Folate (for cell growth and function).
# *   **Antioxidants:** Rich in powerful antioxidants like sulforaphane, indoles, and carotenoids, which help fight oxidative stress and may have anti-cancer properties.
# *   **Low Calorie:** Very low in calories, making it great for weight management.
# *   **Minerals:** Contains potassium (for blood pressure), iron (in smaller amounts), and calcium.
# *   **Anti-inflammatory:** Compounds in broccoli have anti-inflammatory effects.
#
# **Best for:**
# *   Adding bulk and satiety to meals without many calories.
# *   Boosting fiber intake.
# *   Getting a wide array of vitamins (especially C and K) and antioxidants.
# *   Supporting gut health.
#
# ### Eggs: The Complete Package
#
# **Strengths:**
# *   **Complete Protein:** An excellent source of high-quality, complete protein, meaning it contains all nine essential amino acids your body can't produce itself. Great for muscle repair, growth, and satiety.
# *   **Vitamins:** Rich in Vitamin D (one of the few food sources, crucial for bone health and immunity), Vitamin B12 (for energy and nerve function), Riboflavin, and Vitamin A.
# *   **Minerals:** Good source of Selenium (antioxidant), Iron (for oxygen transport), Zinc (for immunity and wound healing), and Phosphorus.
# *   **Choline:** Crucial for brain health, memory, and liver function.
# *   **Eye Health:** Contains Lutein and Zeaxanthin, antioxidants that protect the eyes from age-related macular degeneration and cataracts.
# *   **Healthy Fats:** Contains healthy monounsaturated and polyunsaturated fats, which are important for energy and nutrient absorption.
#
# **Best for:**
# *   Getting high-quality protein to build and repair tissues, and keep you feeling full.
# *   Boosting Vitamin D and B12 intake.
# *   Supporting brain and eye health.
# *   A quick and versatile meal component.
#
# ### The Verdict: Why Not Both?
#
# Instead of choosing one over the other, **the healthiest approach is to include both broccoli and eggs in your diet regularly!**
#
# *   **Complementary Nutrients:** They each fill nutritional gaps the other might have. Broccoli offers fiber and Vitamin C, which eggs lack. Eggs offer complete protein, Vitamin D, and B12, which broccoli provides in much smaller amounts or not at all.
# *   **Balanced Meals:** Combining them makes for incredibly nutritious and satisfying meals. Think scrambled eggs with a side of steamed broccoli, an omelet packed with broccoli florets, or a frittata with both!
#
# **In summary:**
# *   If your primary goal is **fiber, antioxidants, and a low-calorie vegetable punch**, go for **broccoli**.
# *   If your primary goal is **high-quality protein, Vitamin D, B12, and brain/eye-supporting nutrients**, go for **eggs**.
#
# But truly, enjoying both will give you a wider spectrum of essential nutrients for overall health.
