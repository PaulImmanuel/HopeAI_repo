# %%
import google.generativeai as genai

# Configure your API key
genai.configure(api_key="ZZZZZZZZZZZZZZZZZZZZZZZZ")

print("Checking available models for your API key...")
try:
    for model in genai.list_models():
        if 'generateContent' in model.supported_generation_methods:
            print(f"Model ID: {model.name}")
except Exception as e:
    print(f"Failed to fetch models: {e}")
# Out:
# Checking available models for your API key...
# Model ID: models/gemini-2.5-flash
# Model ID: models/gemini-2.5-pro
# Model ID: models/gemini-2.0-flash
# Model ID: models/gemini-2.0-flash-001
# Model ID: models/gemini-2.0-flash-lite-001
# Model ID: models/gemini-2.0-flash-lite
# Model ID: models/gemini-2.5-flash-preview-tts
# Model ID: models/gemini-2.5-pro-preview-tts
# Model ID: models/gemma-4-26b-a4b-it
# Model ID: models/gemma-4-31b-it
# Model ID: models/gemini-flash-latest
# Model ID: models/gemini-flash-lite-latest
# Model ID: models/gemini-pro-latest
# Model ID: models/gemini-2.5-flash-lite
# Model ID: models/gemini-2.5-flash-image
# Model ID: models/gemini-3-pro-preview
# Model ID: models/gemini-3-flash-preview
# Model ID: models/gemini-3.1-pro-preview
# Model ID: models/gemini-3.1-pro-preview-customtools
# Model ID: models/gemini-3.1-flash-lite-preview
# Model ID: models/gemini-3.1-flash-lite
# Model ID: models/gemini-3-pro-image-preview
# ...

# %%
#!pip install google-generativeai==0.8.4
#pip install panel==1.6.1
import google.generativeai as genai

# Configure API key
genai.configure(api_key="zzzzzzzzzzzzzzzzzzzzzz")  # Replace with your actual Gemini API key

# Create a model instance
model = genai.GenerativeModel(model_name="gemini-2.5-flash")

# Generate response
response = model.generate_content("Give me 3 ideas for apps I could build with OpenAI APIs")

# Print output
print(response.text)
# Out:
# Here are 3 ideas for apps you could build using OpenAI APIs, ranging in complexity and focusing on different aspects of what the APIs can do:
#
# ---
#
# ### 1. The Intelligent Meeting Assistant (Whisper + GPT)
#
# **Concept:** An app that records, transcribes, summarizes, and extracts key insights from your meetings (online or in-person).
#
# **How it uses OpenAI APIs:**
# *   **Whisper API:** For highly accurate **speech-to-text transcription** of meeting audio.
# *   **GPT API (e.g., GPT-4):**
#     *   To **summarize** the long transcript into concise bullet points.
#     *   To **extract action items, decisions made, and key discussion points**.
#     *   To identify different **speakers** (though this can be tricky to implement perfectly without advanced speaker diarization, a basic version could just summarize the whole transcript).
#
# **Key Features:**
# *   Record audio directly or upload audio files.
# *   Generate full, searchable transcripts.
# ...
