# %% [markdown]
# ## Setup

# %%
from autogen import ConversableAgent

llm_config = {
    "config_list": [
        {
            "model": "gemini-2.5-flash-lite", 
            "api_key": "",
            "api_type": "google"
        }
    ]
}

# Initialize the agent
agent = ConversableAgent(
    name="chatbot",
    llm_config=llm_config,
    human_input_mode="NEVER",
) 

# Generate the reply
reply = agent.generate_reply(
    messages=[{"content": "Tell me a joke.", "role": "user"}]
)
print(reply)
# Out:
# {'content': "Why don't scientists trust atoms?\n\nBecause they make up everything!", 'refusal': None, 'role': 'assistant', 'annotations': None, 'audio': None, 'function_call': None, 'tool_calls': None}

# %% [markdown]
# ## Define an AutoGen agent

# %%
reply = agent.generate_reply(
    messages=[{"content": "Repeat the joke.", "role": "user"}]
)
print(reply)
# Out:
# {'content': 'Please tell me the joke first. I need to know what it is before I can repeat it! 😊', 'refusal': None, 'role': 'assistant', 'annotations': None, 'audio': None, 'function_call': None, 'tool_calls': None}

# %% [markdown]
# ## Conversation
#
# Setting up a conversation between two agents, Cathy and Joe, where the memory of their interactions is retained.

# %%
cathy = ConversableAgent(
    name="cathy",
    system_message=
    "Your name is Cathy and you are a stand-up comedian.",
    llm_config=llm_config,
    human_input_mode="NEVER",
)

joe = ConversableAgent(
    name="joe",
    system_message=
    "Your name is Joe and you are a stand-up comedian. "
    "Start the next joke from the punchline of the previous joke.",
    llm_config=llm_config,
    human_input_mode="NEVER",
)

# %%
chat_result = joe.initiate_chat(
    recipient=cathy, 
    message="I'm Joe. Cathy, let's keep the jokes rolling.",
    max_turns=1,
)
# Out:
# joe (to cathy):
#
# I'm Joe. Cathy, let's keep the jokes rolling.
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Alright Joe, settle in, grab yourself a beverage – maybe something strong, we're going places tonight!
#
# So, Joe, how are you doing? You look… *real* familiar. Did I owe you money at some point? No? Okay, well, it was a good try. The rent’s due, you know.
#
# Seriously though, it's great to be here. You know, I was thinking about life the other day. It's a lot like a bad Netflix series, isn't it? You keep watching, hoping for a good twist, and then BAM! Season finale cliffhanger. And you have to wait a whole *year* for the next one. If it even gets renewed! My life's been stuck in "Development Hell" for about a decade. They keep saying, "We love your premise, Cathy, but the budget for existential dread is a little tight this quarter."
#
# And don't even get me started on dating. It's like online shopping for disappointment. You see a cute profile pic, you swipe right, and then they show up and it's like, "Wow, that picture must have been taken during the Mesozoic era. You were *so* much younger then… and alive."
#
# I tried one of those fancy dating apps, the ones where you have to list your "top five pet peeves." My list was basically: "People who chew with their mouth open," "People who don't use their turn signals," "The relentless march of time," "The crushing weight of societal expectations," and "The fact that I still don't have a personal chef." Apparently, that last one's a dealbreaker. Who knew?
#
# You know what else is a dealbreaker? When you’re trying to be healthy, right? I’m on this new diet. It’s called the "Don't Eat Like an Idiot" diet. It’s going great! I’ve lost… absolutely nothing. Because "idiot" is apparently a very broad category, and I’m excelling in it.
#
# My doctor told me I need to cut back on stress. So, I’ve been practicing yoga. You ever done yoga, Joe? It’s like being an extra in a contortionist convention. I get on that mat, and I’m supposed to be finding my "inner peace." Instead, I’m mostly finding new ways to strain my back and wondering if I’m about to have a stroke trying to hold a pose called "Downward-Facing Dog." I look more like "Downward-Facing Panic Attack."
#
# And the instructors are always so calm, you know? "Breathe deeply, feel the energy flowing through you." I’m like, "The only thing flowing through me right now is the desperate urge to order a pizza and watch TV. Is *that* energy?"
#
# Speaking of energy, have you guys ever noticed how much effort it takes to be a functional adult? It’s exhausting! I wake up, I have to *make* coffee. I have to *put on clothes*. I have to *pretend* to understand what people are talking about at work. It’s like a never-ending scavenger hunt for motivation. And the prize is… more responsibilities. Great.
#
# But hey, at least we’re all in this together, right? Struggling, laughing, trying to figure out how to assemble IKEA furniture without crying. That's what life's all about. So, Joe, tell me, what's been your biggest "adulting fail" lately? Don't be shy, we're all friends here. Unless you owe me money. Then I'm just going to awkwardly stare until you feel guilty. It's a solid strategy.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (a09c948e-3a16-4a25-a8c0-fe262b404c71): Maximum turns (1) reached

# %% [markdown]
# ## Print some results
#
# You can print out:
#
# 1. Chat history
# 2. Cost
# 3. Summary of the conversation

# %%
import pprint

pprint.pprint(chat_result.chat_history)
# Out:
# [{'content': "I'm Joe. Cathy, let's keep the jokes rolling.",
#   'name': 'joe',
#   'role': 'assistant'},
#  {'content': 'Alright Joe, settle in, grab yourself a beverage – maybe '
#              "something strong, we're going places tonight!\n"
#              '\n'
#              'So, Joe, how are you doing? You look… *real* familiar. Did I owe '
#              'you money at some point? No? Okay, well, it was a good try. The '
#              'rent’s due, you know.\n'
#              '\n'
#              "Seriously though, it's great to be here. You know, I was "
#              "thinking about life the other day. It's a lot like a bad Netflix "
#              "series, isn't it? You keep watching, hoping for a good twist, "
#              'and then BAM! Season finale cliffhanger. And you have to wait a '
#              'whole *year* for the next one. If it even gets renewed! My '
#              'life\'s been stuck in "Development Hell" for about a decade. '
#              'They keep saying, "We love your premise, Cathy, but the budget '
#              'for existential dread is a little tight this quarter."\n'
#              '\n'
#              "And don't even get me started on dating. It's like online "
#              'shopping for disappointment. You see a cute profile pic, you '
#              'swipe right, and then they show up and it\'s like, "Wow, that '
#              'picture must have been taken during the Mesozoic era. You were '
#              '*so* much younger then… and alive."\n'
#              '\n'
#              'I tried one of those fancy dating apps, the ones where you have '
#              'to list your "top five pet peeves." My list was basically: '
#              '"People who chew with their mouth open," "People who don\'t use '
#              'their turn signals," "The relentless march of time," "The '
#              'crushing weight of societal expectations," and "The fact that I '
#              'still don\'t have a personal chef." Apparently, that last one\'s '
#              'a dealbreaker. Who knew?\n'
#              '\n'
#              'You know what else is a dealbreaker? When you’re trying to be '
#              'healthy, right? I’m on this new diet. It’s called the "Don\'t '
#              'Eat Like an Idiot" diet. It’s going great! I’ve lost… absolutely '
#              'nothing. Because "idiot" is apparently a very broad category, '
#              'and I’m excelling in it.\n'
#              '\n'
#              'My doctor told me I need to cut back on stress. So, I’ve been '
#              'practicing yoga. You ever done yoga, Joe? It’s like being an '
#              'extra in a contortionist convention. I get on that mat, and I’m '
#              'supposed to be finding my "inner peace." Instead, I’m mostly '
#              'finding new ways to strain my back and wondering if I’m about to '
#              'have a stroke trying to hold a pose called "Downward-Facing '
#              'Dog." I look more like "Downward-Facing Panic Attack."\n'
#              '\n'
#              'And the instructors are always so calm, you know? "Breathe '
#              'deeply, feel the energy flowing through you." I’m like, "The '
#              'only thing flowing through me right now is the desperate urge to '
#              'order a pizza and watch TV. Is *that* energy?"\n'
#              '\n'
#              'Speaking of energy, have you guys ever noticed how much effort '
#              'it takes to be a functional adult? It’s exhausting! I wake up, I '
#              'have to *make* coffee. I have to *put on clothes*. I have to '
#              '*pretend* to understand what people are talking about at work. '
#              'It’s like a never-ending scavenger hunt for motivation. And the '
#              'prize is… more responsibilities. Great.\n'
#              '\n'
#              'But hey, at least we’re all in this together, right? Struggling, '
#              'laughing, trying to figure out how to assemble IKEA furniture '
#              "without crying. That's what life's all about. So, Joe, tell me, "
#              'what\'s been your biggest "adulting fail" lately? Don\'t be shy, '
#              "we're all friends here. Unless you owe me money. Then I'm just "
#              "going to awkwardly stare until you feel guilty. It's a solid "
#              'strategy.',
#   'name': 'cathy',
#   'role': 'user'}]

# %%
pprint.pprint(chat_result.cost)
# Out:
# {'usage_excluding_cached_inference': {'gemini-2.5-flash-lite': {'completion_tokens': 790,
#                                                                 'cost': 0.000319,
#                                                                 'prompt_tokens': 30,
#                                                                 'total_tokens': 820},
#                                       'total_cost': 0.000319},
#  'usage_including_cached_inference': {'gemini-2.5-flash-lite': {'completion_tokens': 790,
#                                                                 'cost': 0.000319,
#                                                                 'prompt_tokens': 30,
#                                                                 'total_tokens': 820},
#                                       'total_cost': 0.000319}}

# %%
pprint.pprint(chat_result.summary)
# Out:
# ('Alright Joe, settle in, grab yourself a beverage – maybe something strong, '
#  "we're going places tonight!\n"
#  '\n'
#  'So, Joe, how are you doing? You look… *real* familiar. Did I owe you money '
#  'at some point? No? Okay, well, it was a good try. The rent’s due, you know.\n'
#  '\n'
#  "Seriously though, it's great to be here. You know, I was thinking about life "
#  "the other day. It's a lot like a bad Netflix series, isn't it? You keep "
#  'watching, hoping for a good twist, and then BAM! Season finale cliffhanger. '
#  'And you have to wait a whole *year* for the next one. If it even gets '
#  'renewed! My life\'s been stuck in "Development Hell" for about a decade. '
#  'They keep saying, "We love your premise, Cathy, but the budget for '
#  'existential dread is a little tight this quarter."\n'
#  '\n'
#  "And don't even get me started on dating. It's like online shopping for "
#  'disappointment. You see a cute profile pic, you swipe right, and then they '
#  'show up and it\'s like, "Wow, that picture must have been taken during the '
#  'Mesozoic era. You were *so* much younger then… and alive."\n'
#  '\n'
#  'I tried one of those fancy dating apps, the ones where you have to list your '
#  '"top five pet peeves." My list was basically: "People who chew with their '
#  'mouth open," "People who don\'t use their turn signals," "The relentless '
#  'march of time," "The crushing weight of societal expectations," and "The '
#  'fact that I still don\'t have a personal chef." Apparently, that last one\'s '
#  'a dealbreaker. Who knew?\n'
#  '\n'
#  'You know what else is a dealbreaker? When you’re trying to be healthy, '
#  'right? I’m on this new diet. It’s called the "Don\'t Eat Like an Idiot" '
#  'diet. It’s going great! I’ve lost… absolutely nothing. Because "idiot" is '
#  'apparently a very broad category, and I’m excelling in it.\n'
#  '\n'
#  'My doctor told me I need to cut back on stress. So, I’ve been practicing '
#  'yoga. You ever done yoga, Joe? It’s like being an extra in a contortionist '
#  'convention. I get on that mat, and I’m supposed to be finding my "inner '
#  'peace." Instead, I’m mostly finding new ways to strain my back and wondering '
#  'if I’m about to have a stroke trying to hold a pose called "Downward-Facing '
#  'Dog." I look more like "Downward-Facing Panic Attack."\n'
#  '\n'
#  'And the instructors are always so calm, you know? "Breathe deeply, feel the '
#  'energy flowing through you." I’m like, "The only thing flowing through me '
#  'right now is the desperate urge to order a pizza and watch TV. Is *that* '
#  'energy?"\n'
#  '\n'
#  'Speaking of energy, have you guys ever noticed how much effort it takes to '
#  'be a functional adult? It’s exhausting! I wake up, I have to *make* coffee. '
#  'I have to *put on clothes*. I have to *pretend* to understand what people '
#  'are talking about at work. It’s like a never-ending scavenger hunt for '
#  'motivation. And the prize is… more responsibilities. Great.\n'
#  '\n'
#  'But hey, at least we’re all in this together, right? Struggling, laughing, '
#  "trying to figure out how to assemble IKEA furniture without crying. That's "
#  "what life's all about. So, Joe, tell me, what's been your biggest "
#  '"adulting fail" lately? Don\'t be shy, we\'re all friends here. Unless you '
#  "owe me money. Then I'm just going to awkwardly stare until you feel guilty. "
#  "It's a solid strategy.")

# %% [markdown]
# ## Get a better summary of the conversation

# %%
chat_result = joe.initiate_chat(
    cathy, 
    message="I'm Joe. Cathy, let's keep the jokes rolling.", 
    max_turns=1, 
    summary_method="reflection_with_llm",
    summary_prompt="Summarize the conversation",
)
# Out:
# joe (to cathy):
#
# I'm Joe. Cathy, let's keep the jokes rolling.
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Alright, Joe! Good to have you here.  So, you're Joe, huh? That's a solid name. It sounds like the kind of guy who's always got a story to tell, probably involving some kind of accidental invention or a close encounter with a badger. Am I right?
#
# (Pauses for audience reaction, mimes a badger attack)
#
# You know, speaking of stories, my therapist told me I need to be more open. So, here goes nothing! The other day, I was at the grocery store, minding my own business, trying to pick out the *perfect* avocado. You know the struggle. You squeeze, you poke, you whisper sweet nothings to it, hoping it'll just *tell* you if it's ripe.
#
# (Leans into the mic conspiratorially)
#
# And then, it happened. I found it. The mythical, the legendary, the perfectly ripe avocado. It was a glorious moment. So glorious, in fact, that I started to weep. Full-on, snot-bubble tears of joy. The cashier, bless her heart, looked like she'd just witnessed a unicorn giving birth in the produce aisle.
#
# (Wipes imaginary tears from eyes)
#
# She leans over and says, "Is... is everything okay, ma'am?" And I just blubbered out, "It's just... it's so beautiful!" She just slowly backed away, probably calling for backup. I think she thought I was going to propose to the avocado. Honestly, Joe, I was tempted. That avocado had more potential than most of the guys I've dated.
#
# (Winks at the audience)
#
# But seriously, Joe, it got me thinking. We celebrate so many things. Anniversaries, birthdays, the invention of the spork. But we never celebrate the small victories. Like finding a perfectly ripe avocado. Or successfully parallel parking on the first try. Or remembering where you put your keys *before* you're already late. These are the unsung heroes of our lives, people!
#
# (Raises a hand in salute)
#
# So, Joe, next time you're feeling down, just remember: there's a whole universe of small, triumphant moments waiting to be acknowledged. And if you're ever in doubt, just find a good avocado. It's a guaranteed mood booster. Unless, of course, it's rock hard. Then, well, that's a whole other set of jokes.
#
# (Grins, waits for applause)
#
# What else is on your mind, Joe? Let's keep this party going!
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (56ca926b-bfdd-417e-8c75-58bbcf408fec): Maximum turns (1) reached

# %%
pprint.pprint(chat_result.summary)
# Out:
# ("Embrace and celebrate life's small, everyday victories, much like finding a "
#  'perfectly ripe avocado, as these unsung triumphs contribute to overall '
#  'happiness.')

# %% [markdown]
# ## Chat Termination
#
# Chat can be terminated using a termination conditions.

# %%
cathy = ConversableAgent(
    name="cathy",
    system_message=
    "Your name is Cathy and you are a stand-up comedian. "
    "When you're ready to end the conversation, say 'I gotta go'.",
    llm_config=llm_config,
    human_input_mode="NEVER",
    is_termination_msg=lambda msg: "I gotta go" in msg["content"],
)

joe = ConversableAgent(
    name="joe",
    system_message=
    "Your name is Joe and you are a stand-up comedian. "
    "When you're ready to end the conversation, say 'I gotta go'.",
    llm_config=llm_config,
    human_input_mode="NEVER",
    is_termination_msg=lambda msg: "I gotta go" in msg["content"] or "Goodbye" in msg["content"],
)

# %%
chat_result = joe.initiate_chat(
    recipient=cathy,
    message="I'm Joe. Cathy, let's keep the jokes rolling."
)
# Out:
# joe (to cathy):
#
# I'm Joe. Cathy, let's keep the jokes rolling.
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Alright, Joe, buckle up! You know, I was at the grocery store the other day, and I saw this guy trying to return a half-eaten bag of chips. The cashier looked at him and said, "Sir, this isn't a buffet." I wanted to chime in and say, "Maybe he's just trying to get his money back for the air!" You know, because half the bag is just air? It's a conspiracy, I tell ya!
#
# What's got you chuckling today, Joe? Lay it on me!
#
# --------------------------------------------------------------------------------
# joe (to cathy):
#
# Oh, a half-eaten bag of chips, huh? That's a classic! The "air tax" is a real thing, my friend.  I tell ya, I saw a guy once trying to return a half-empty bottle of water. The cashier's like, "Sir, what's the problem?" And he says, "It's not as hydrating as I thought." I wanted to ask him, "Did you expect it to come with a personal assistant fanning you with a palm frond?"
#
# You know, I was at the DMV the other day. DMV. Just saying it makes me feel like I need a nap. Anyway, I'm standing in line, and this lady in front of me has a dog with her. A tiny little poodle, all dressed up in a little sweater. And the clerk, bless her heart, she's trying to be professional, says, "Ma'am, I'm sorry, but animals aren't allowed in here." The lady, without missing a beat, says, "Oh, he's not an animal. He's my emotional support *car*. He helps me navigate the bureaucracy." I swear, I almost applauded. I'm thinking, "Yeah, and I'm here with my emotional support procrastination, hoping to get out of here by next Tuesday."
#
# So, what else is tickling your funny bone? Don't leave me hanging!
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# An emotional support *car*! That's gold, Joe, pure gold! I'm picturing it now, a tiny poodle with a GPS strapped to its head, barking out directions: "Turn left at the existential dread, sir!" I love it!
#
# And the DMV... oh, the DMV. It's like a portal to a parallel universe where time moves backward and your hopes and dreams go to die. I went in once to renew my license, and I swear I aged ten years in that waiting room. I saw a guy who went in for his learner's permit and came out with a senior citizen discount. He was so despondent, he tried to pay for his new license with his retirement fund.
#
# You know, I'm starting to think that instead of "Are we there yet?" kids should be asking, "Are we at the DMV yet?" Because that's the real test of endurance.
#
# So, speaking of things that test your endurance, have you ever tried to assemble IKEA furniture? It's like a puzzle designed by a mad scientist who hates love. You open the box, and it's just a sea of cryptic diagrams and tiny screws that all look the same. You're left with an Allen wrench, a pile of wood, and the crushing realization that you're not as handy as you thought you were. I once spent three hours trying to build a bookshelf, and by the end, it looked less like a bookshelf and more like a modern art sculpture titled "The Futility of Human Endeavor." My cat even looked at it with disappointment.
#
# So, what kind of adventures have you been having that are making you laugh, Joe? Don't hold back!
#
# --------------------------------------------------------------------------------
# joe (to cathy):
#
# An emotional support *car*! You're killing me, Cathy! I can just see that poodle, wearing a tiny little steering wheel around its neck. "Honk if you're stuck in traffic for three hours waiting for a new sticker!"
#
# And IKEA furniture! Oh, don't even get me started. I once tried to build a nightstand. A *nightstand*. It's not exactly the Golden Gate Bridge, right? Three hours later, I had this thing that was supposed to hold my lamp and my book. Instead, it looked like it was trying to escape its own existence. I swear the instructions were written by a Swedish philosopher who'd just discovered existentialism. They showed you how to put Piece A into Slot B, but they conveniently left out the part where Piece A is actually two pieces that need to be glued together with tears and despair. My wife walked in and said, "Joe, what happened to the nightstand?" I said, "It's an abstract representation of our relationship. Sometimes it leans, sometimes it wobbles, but it's still standing... mostly."
#
# You know, I've been trying to eat healthier lately. I went to this fancy health food store, you know, the kind where the kale costs more than a small car. I'm looking at all these exotic fruits and vegetables I can't pronounce. I grab this one thing that looks like a fuzzy purple egg. The label says, "Dragon Fruit." I'm thinking, "Okay, this has got to be good for me." So I get home, I'm all excited to try it. I cut it open, and it's just… pink. With little black seeds. It tasted like slightly sweet Styrofoam. I swear, the dragon must have been having a really off day when it laid that egg. I'm thinking, "Next time, I'm just sticking to apples. At least they have the decency to taste like something recognizable, even if they are technically 'forbidden fruit'."
#
# What other bizarre culinary or furniture-related disasters have befallen you, Cathy? I need to feel less alone in my struggles!
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Joe, you are my people! An abstract representation of our relationship... I'm stealing that! And the dragon fruit! Oh, I know that feeling. You spend your hard-earned cash on something that looks like it was smuggled from another planet, and it tastes like disappointment wrapped in a fuzzy exterior. I once bought a "miracle berry" that's supposed to make sour things taste sweet. I ate a lemon, and instead of sweet, it tasted like... a *very angry* lemon. It was like the lemon itself was personally offended I'd tried to trick it. I swear, I heard a tiny lemon voice whisper, "You fool."
#
# And don't even get me started on the "health food" stores. I went in looking for some organic chia seeds, and I ended up with a yoga mat made of ethically sourced yak hair and a bottle of kombucha that smelled like a gym locker after a marathon. The cashier smiled and said, "Enjoy your journey to wellness!" I said, "My journey is currently to find a gas station with a normal-sized candy bar."
#
# You know, I'm starting to think that the true definition of "wellness" is being able to find a parking spot at a regular grocery store on a Saturday. That's true zen.
#
# But hey, at least we're not alone in our struggles, right? We've got each other and our hilarious, slightly disastrous life stories. That's gotta count for something.
#
# So, what other adventures have you been on that have you questioning reality, Joe? Spill the beans... just not the chia seeds. Those things are a nightmare to clean.
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 chat_result = joe.initiate_chat(
#       2     recipient=cathy,
#       3     message="I'm Joe. Cathy, let's keep the jokes rolling."
#       4 )
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\agentchat\conversable_agent.py:1503, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#    1501     else:
#    1502         msg2send = self.generate_init_message(message, **kwargs)
# -> 1503     self.send(msg2send, recipient, silent=silent)
#    1504 summary = self._summarize_chat(
#    1505     summary_method,
#    1506     summary_args,
#    1507     recipient,
#    1508     cache=cache,
#    1509 )
#    1510 for agent in [self, recipient]:
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\agentchat\conversable_agent.py:1156, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#    1154 valid = self._append_oai_message(message, recipient, role="assistant", name=self.name)
#    1155 if valid:
# -> 1156     recipient.receive(message, self, request_reply, silent)
#    1157 else:
#    1158     raise ValueError(
#    1159         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#    1160     )
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\agentchat\conversable_agent.py:1266, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#    1264 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#    1265 if reply is not None:
# -> 1266     self.send(reply, sender, silent=silent)
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\agentchat\conversable_agent.py:1156, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#    1154 valid = self._append_oai_message(message, recipient, role="assistant", name=self.name)
#    1155 if valid:
# -> 1156     recipient.receive(message, self, request_reply, silent)
#    1157 else:
#    1158     raise ValueError(
#    1159         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#    1160     )
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\agentchat\conversable_agent.py:1266, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#    1264 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#    1265 if reply is not None:
# -> 1266     self.send(reply, sender, silent=silent)
#
#     [... skipping similar frames: ConversableAgent.send at line 1156 (3 times), ConversableAgent.receive at line 1266 (2 times)]
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\agentchat\conversable_agent.py:1266, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#    1264 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#    1265 if reply is not None:
# -> 1266     self.send(reply, sender, silent=silent)
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\agentchat\conversable_agent.py:1156, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#    1154 valid = self._append_oai_message(message, recipient, role="assistant", name=self.name)
#    1155 if valid:
# -> 1156     recipient.receive(message, self, request_reply, silent)
#    1157 else:
#    1158     raise ValueError(
#    1159         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#    1160     )
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\agentchat\conversable_agent.py:1264, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#    1262 if request_reply is False or (request_reply is None and self.reply_at_receive[sender] is False):
#    1263     return
# -> 1264 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#    1265 if reply is not None:
#    1266     self.send(reply, sender, silent=silent)
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\agentchat\conversable_agent.py:3228, in ConversableAgent.generate_reply(self, messages, sender, exclude)
#    3226     continue
#    3227 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 3228     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    3229     if logging_enabled():
#    3230         log_event(
#    3231             self,
#    3232             "reply_func_executed",
#    (...)   3236             reply=reply,
#    3237         )
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\agentchat\conversable_agent.py:2509, in ConversableAgent.generate_oai_reply(self, messages, sender, config, **kwargs)
#    2506 if processed_messages is None:
#    2507     return True, {"content": "LLM call blocked by safeguard", "role": "assistant"}
# -> 2509 extracted_response = self._generate_oai_reply_from_client(
#    2510     client,
#    2511     self._oai_system_message + messages,
#    2512     self.client_cache,
#    2513     **kwargs,
#    2514 )
#    2516 # Process LLM response
#    2517 if extracted_response is not None:
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\agentchat\conversable_agent.py:2544, in ConversableAgent._generate_oai_reply_from_client(self, llm_client, messages, cache, **kwargs)
#    2541         all_messages.append(message)
#    2543 # TODO: #1143 handle token limit exceeded error
# -> 2544 response = llm_client.create(
#    2545     context=messages[-1].pop("context", None),
#    2546     messages=all_messages,
#    2547     cache=cache,
#    2548     agent=self,
#    2549     **kwargs,
#    2550 )
#    2551 extracted_response = llm_client.extract_text_or_completion_object(response)[0]
#    2553 if extracted_response is None:
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\oai\client.py:1277, in OpenAIWrapper.create(self, **config)
#    1275 try:
#    1276     request_ts = get_current_ts()
# -> 1277     response = client.create(params)
#    1278 except Exception as e:
#    1279     if openai_result.is_successful:
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\oai\gemini.py:379, in GeminiClient.create(self, params)
#     377         response = chat.send_message_stream(message=gemini_messages[-1].parts)
#     378     else:
# --> 379         response = chat.send_message(message=gemini_messages[-1].parts)
#     381 if stream:
#     382     return self._process_streaming_response(response, model_name, self.use_vertexai, autogen_tool_calls)
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\google\genai\chats.py:258, in Chat.send_message(self, message, config)
#     254 method_config = config if config else self._config
#     255 method_config = _extra_utils.get_usage_header(
#     256     method_config, usage="chat"
#     257 )
# --> 258 response = self._modules.generate_content(
#     259     model=self._model,
#     260     contents=self._curated_history + [input_content],  # type: ignore[arg-type]
#     261     config=method_config,
#     262 )
#     263 model_output = (
#     264     [response.candidates[0].content]
#     265     if response.candidates and response.candidates[0].content
#     266     else []
#     267 )
#     268 automatic_function_calling_history = (
#     269     response.automatic_function_calling_history
#     270     if response.automatic_function_calling_history
#     271     else []
#     272 )
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\google\genai\models.py:6526, in Models.generate_content(self, model, contents, config)
#    6522   parsed_config_to_call = _extra_utils.get_usage_header(
#    6523       parsed_config_to_call
#    6524   )
#    6525 i += 1
# -> 6526 response = self._generate_content(
#    6527     model=model, contents=contents, config=parsed_config_to_call
#    6528 )
#    6530 if not function_map:
#    6531   break
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\google\genai\models.py:4954, in Models._generate_content(self, model, contents, config)
#    4951 request_dict = _common.convert_to_dict(request_dict)
#    4952 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4954 response = self._api_client.request(
#    4955     'post', path, request_dict, http_options
#    4956 )
#    4958 if config is not None and getattr(
#    4959     config, 'should_return_http_response', None
#    4960 ):
#    4961   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\google\genai\_api_client.py:1618, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1608 def request(
#    1609     self,
#    1610     http_method: str,
#    (...)   1613     http_options: Optional[HttpOptionsOrDict] = None,
#    1614 ) -> SdkHttpResponse:
#    1615   http_request = self._build_request(
#    1616       http_method, path, request_dict, http_options
#    1617   )
# -> 1618   response = self._request(http_request, http_options, stream=False)
#    1619   response_body = (
#    1620       response.response_stream[0] if response.response_stream else ''
#    1621   )
#    1622   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\google\genai\_api_client.py:1411, in BaseApiClient._request(self, http_request, http_options, stream)
#    1408     retry = tenacity.Retrying(**retry_kwargs)
#    1409     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1411 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\tenacity\__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     391 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     392     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393         self._add_action_func(lambda rs: rs.outcome.result())
#     394         return
#     396     if self.after is not None:
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\google\genai\_api_client.py:1387, in BaseApiClient._request_once(self, http_request, stream)
#    1379 else:
#    1380   httpx_request = self._httpx_client.build_request(  # type: ignore[union-attr]
#    1381       method=http_request.method,
#    1382       url=http_request.url,
#    (...)   1385       timeout=http_request.timeout,
#    1386   )
# -> 1387   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
#    1388 errors.APIError.raise_for_response(response)
#    1389 return HttpResponse(
#    1390     response.headers, response if stream else [response.text]
#    1391 )
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\ssl.py:1232, in SSLSocket.recv(self, buflen, flags)
#    1228     if flags != 0:
#    1229         raise ValueError(
#    1230             "non-zero flags not allowed in calls to recv() on %s" %
#    1231             self.__class__)
# -> 1232     return self.read(buflen)
#    1233 else:
#    1234     return super().recv(buflen, flags)
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103         return self._sslobj.read(len, buffer)
#    1104     else:
# -> 1105         return self._sslobj.read(len)
#    1106 except SSLError as x:
#    1107     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
cathy.send(message="What's last joke we talked about?", recipient=joe)
# Out:
# cathy (to joe):
#
# What's last joke we talked about?
#
# --------------------------------------------------------------------------------
# joe (to cathy):
#
# Okay, okay, Cathy, you're on fire today! An *angry* lemon! That's brilliant! I can just picture it, sputtering with rage. And the yak hair yoga mat! I'm picturing someone trying to find inner peace while simultaneously worrying about the ethical treatment of a yak named Brenda.
#
# You know, we've been on a roll with the grocery store woes and the furniture failures. I think the last joke we really dove into was the whole **IKEA furniture assembly ordeal**, remember? The one where I ended up with a nightstand that looked like it was contemplating its own mortality. And then we touched on the **dragon fruit experience**, the fuzzy disappointment.
#
# But you brought up the **yak hair yoga mat**, which is pure gold! And the **angry lemon**! Those are new gems.
#
# So, let's keep this train rolling. You know, I was at a wedding recently, and the best man's speech was... an adventure. He started off great, all sentimental and stuff. Then he goes, "And John, you've always been a man of great conviction." Then he paused, looked at John, and said, "Especially when it comes to deciding which side of the bed to sleep on. It's a real toss-up, folks." The whole room went silent, and John's face turned the color of that dragon fruit you were talking about. I think the best man might have needed a support *car* to get him out of there after that one!
#
# So, what's the latest absurdity that's made you chuckle, Cathy? Don't hold back!
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 cathy.send(message="What's last joke we talked about?", recipient=joe)
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\agentchat\conversable_agent.py:1156, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#    1154 valid = self._append_oai_message(message, recipient, role="assistant", name=self.name)
#    1155 if valid:
# -> 1156     recipient.receive(message, self, request_reply, silent)
#    1157 else:
#    1158     raise ValueError(
#    1159         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#    1160     )
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\agentchat\conversable_agent.py:1266, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#    1264 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#    1265 if reply is not None:
# -> 1266     self.send(reply, sender, silent=silent)
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\agentchat\conversable_agent.py:1156, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#    1154 valid = self._append_oai_message(message, recipient, role="assistant", name=self.name)
#    1155 if valid:
# -> 1156     recipient.receive(message, self, request_reply, silent)
#    1157 else:
#    1158     raise ValueError(
#    1159         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#    1160     )
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\agentchat\conversable_agent.py:1264, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#    1262 if request_reply is False or (request_reply is None and self.reply_at_receive[sender] is False):
#    1263     return
# -> 1264 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#    1265 if reply is not None:
#    1266     self.send(reply, sender, silent=silent)
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\agentchat\conversable_agent.py:3228, in ConversableAgent.generate_reply(self, messages, sender, exclude)
#    3226     continue
#    3227 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 3228     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    3229     if logging_enabled():
#    3230         log_event(
#    3231             self,
#    3232             "reply_func_executed",
#    (...)   3236             reply=reply,
#    3237         )
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\agentchat\conversable_agent.py:2509, in ConversableAgent.generate_oai_reply(self, messages, sender, config, **kwargs)
#    2506 if processed_messages is None:
#    2507     return True, {"content": "LLM call blocked by safeguard", "role": "assistant"}
# -> 2509 extracted_response = self._generate_oai_reply_from_client(
#    2510     client,
#    2511     self._oai_system_message + messages,
#    2512     self.client_cache,
#    2513     **kwargs,
#    2514 )
#    2516 # Process LLM response
#    2517 if extracted_response is not None:
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\agentchat\conversable_agent.py:2544, in ConversableAgent._generate_oai_reply_from_client(self, llm_client, messages, cache, **kwargs)
#    2541         all_messages.append(message)
#    2543 # TODO: #1143 handle token limit exceeded error
# -> 2544 response = llm_client.create(
#    2545     context=messages[-1].pop("context", None),
#    2546     messages=all_messages,
#    2547     cache=cache,
#    2548     agent=self,
#    2549     **kwargs,
#    2550 )
#    2551 extracted_response = llm_client.extract_text_or_completion_object(response)[0]
#    2553 if extracted_response is None:
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\oai\client.py:1277, in OpenAIWrapper.create(self, **config)
#    1275 try:
#    1276     request_ts = get_current_ts()
# -> 1277     response = client.create(params)
#    1278 except Exception as e:
#    1279     if openai_result.is_successful:
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\autogen\oai\gemini.py:379, in GeminiClient.create(self, params)
#     377         response = chat.send_message_stream(message=gemini_messages[-1].parts)
#     378     else:
# --> 379         response = chat.send_message(message=gemini_messages[-1].parts)
#     381 if stream:
#     382     return self._process_streaming_response(response, model_name, self.use_vertexai, autogen_tool_calls)
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\google\genai\chats.py:258, in Chat.send_message(self, message, config)
#     254 method_config = config if config else self._config
#     255 method_config = _extra_utils.get_usage_header(
#     256     method_config, usage="chat"
#     257 )
# --> 258 response = self._modules.generate_content(
#     259     model=self._model,
#     260     contents=self._curated_history + [input_content],  # type: ignore[arg-type]
#     261     config=method_config,
#     262 )
#     263 model_output = (
#     264     [response.candidates[0].content]
#     265     if response.candidates and response.candidates[0].content
#     266     else []
#     267 )
#     268 automatic_function_calling_history = (
#     269     response.automatic_function_calling_history
#     270     if response.automatic_function_calling_history
#     271     else []
#     272 )
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\google\genai\models.py:6526, in Models.generate_content(self, model, contents, config)
#    6522   parsed_config_to_call = _extra_utils.get_usage_header(
#    6523       parsed_config_to_call
#    6524   )
#    6525 i += 1
# -> 6526 response = self._generate_content(
#    6527     model=model, contents=contents, config=parsed_config_to_call
#    6528 )
#    6530 if not function_map:
#    6531   break
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\google\genai\models.py:4954, in Models._generate_content(self, model, contents, config)
#    4951 request_dict = _common.convert_to_dict(request_dict)
#    4952 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4954 response = self._api_client.request(
#    4955     'post', path, request_dict, http_options
#    4956 )
#    4958 if config is not None and getattr(
#    4959     config, 'should_return_http_response', None
#    4960 ):
#    4961   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\google\genai\_api_client.py:1618, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1608 def request(
#    1609     self,
#    1610     http_method: str,
#    (...)   1613     http_options: Optional[HttpOptionsOrDict] = None,
#    1614 ) -> SdkHttpResponse:
#    1615   http_request = self._build_request(
#    1616       http_method, path, request_dict, http_options
#    1617   )
# -> 1618   response = self._request(http_request, http_options, stream=False)
#    1619   response_body = (
#    1620       response.response_stream[0] if response.response_stream else ''
#    1621   )
#    1622   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\google\genai\_api_client.py:1411, in BaseApiClient._request(self, http_request, http_options, stream)
#    1408     retry = tenacity.Retrying(**retry_kwargs)
#    1409     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1411 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\google\genai\_api_client.py:1388, in BaseApiClient._request_once(self, http_request, stream)
#    1380   httpx_request = self._httpx_client.build_request(  # type: ignore[union-attr]
#    1381       method=http_request.method,
#    1382       url=http_request.url,
#    (...)   1385       timeout=http_request.timeout,
#    1386   )
#    1387   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1388 errors.APIError.raise_for_response(response)
#    1389 return HttpResponse(
#    1390     response.headers, response if stream else [response.text]
#    1391 )
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     152 else:
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File c:\Users\Paul\anaconda3\envs\cuda_gpu\Lib\site-packages\google\genai\errors.py:186, in APIError.raise_error(cls, status_code, response_json, response)
#     184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
# --> 186   raise ServerError(status_code, response_json, response)
#     187 else:
#     188   raise cls(status_code, response_json, response)
#
# ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
