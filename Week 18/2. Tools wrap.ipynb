# %%
import os
from dotenv import load_dotenv
from langchain_ollama import ChatOllama
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.agents import Tool

# 🔸 Step 1: Initialize the LLM
llm = ChatOllama(
    model="llama3",
    temperature=0
)
# 🔸 Step 2: Create a prompt template
prompt = PromptTemplate.from_template("Answer clearly: {question}")

# 🔸 Step 3: Build the LLMChain
qa_chain = LLMChain(llm=llm, prompt=prompt)

# 🔸 Step 4: Wrap LLMChain as a Tool
qa_tool = Tool(
    name="Simple QA",
    func=qa_chain.run,
    description="A basic LLM chain that answers clear questions"
)

# 🔸 Step 5: Use the Tool directly
query = "What is LangGraph in LangChain?"
answer = qa_tool.run(query)

# 🖨️ Output
print("\nUser Question:", query)
print("\nTool Answer:", answer)
# Out:
# C:\Users\Paul\AppData\Local\Temp\ipykernel_19520\3015611896.py:21: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   qa_chain = LLMChain(llm=llm, prompt=prompt)
# User Question: What is LangGraph in LangChain?
#
# Tool Answer: In LangChain, LangGraph refers to a graph-based language model that represents the input text as a graph structure. This allows for more effective processing and analysis of complex linguistic relationships within the text.
#
# LangGraph is designed to capture the hierarchical and contextualized nature of natural language, enabling it to better understand nuances such as:
#
# 1. **Dependency relationships**: LangGraph models the grammatical dependencies between words, including subject-verb-object relationships.
# 2. **Semantic roles**: It identifies the roles played by entities in a sentence, like "agent", "patient", or "theme".
# 3. **Coreference chains**: LangGraph tracks pronouns and their corresponding antecedents to maintain context across sentences.
#
# By representing text as a graph, LangChain's LangGraph can:
#
# 1. **Improve contextual understanding**: By considering the relationships between words, LangGraph can better comprehend the nuances of language.
# 2. **Enhance semantic search**: LangGraph enables more accurate retrieval of relevant information from large datasets.
# 3. **Support advanced NLP tasks**: LangGraph's graph-based representation facilitates tasks like question answering, text classification, and sentiment analysis.
#
# In summary, LangGraph in LangChain is a powerful tool for analyzing complex linguistic relationships within text, enabling more effective natural language processing and understanding.
