# %%
import os
from dotenv import load_dotenv
from langchain_ollama import ChatOllama
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.agents import Tool
from langchain.tools import TavilySearchResults

# 🔐 Load API keys
load_dotenv(dotenv_path=".env")
# openai_api_key = os.getenv("OPENAI_API_KEY")
tavily_api_key = os.getenv("TAVILY_API_KEY")

# 🔸 Initialize LLM
llm = ChatOllama(model="llama3", temperature=0)

# ✅ Tool 1: Simple QA
qa_prompt = PromptTemplate.from_template("Answer clearly: {question}")
qa_chain = LLMChain(llm=llm, prompt=qa_prompt)
qa_tool = Tool(
    name="Simple QA",
    func=qa_chain.run,
    description="Answer factual questions clearly"
)

# ✅ Tool 2: Summarizer
summary_prompt = PromptTemplate.from_template("Summarize the following text:\n\n{text}")
summary_chain = LLMChain(llm=llm, prompt=summary_prompt)
summary_tool = Tool(
    name="Summarizer",
    func=summary_chain.run,
    description="Summarizes input text"
)

# ✅ Tool 3: Web Search (Tavily)
search_tool = Tool(
    name="Web Search",
    func=TavilySearchResults(max_results=3).run,
    description="Search the internet for current information"
)

# 🧪 Run each tool manually
qa_query = "What is LangGraph in LangChain?"
summary_text = """
LangGraph is a framework for building stateful multi-step agents using LangChain. 
It uses graph-based design to model agent workflows and memory.
"""
search_query = "Latest updates on the new GPT-5.6 by OpenAI"

print("\n🧠 Simple QA Tool Output:\n", qa_tool.run({"question": qa_query}))
print("\n📝 Summarizer Tool Output:\n", summary_tool.run({"text": summary_text}))
print("\n🌐 Web Search Tool Output:\n", search_tool.run(search_query))
# Out:
# C:\Users\Paul\AppData\Local\Temp\ipykernel_9136\4283440247.py:19: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   qa_chain = LLMChain(llm=llm, prompt=qa_prompt)
# C:\Users\Paul\AppData\Local\Temp\ipykernel_9136\4283440247.py:38: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-tavily package and should be used instead. To use it run `pip install -U :class:`~langchain-tavily` and import as `from :class:`~langchain_tavily import TavilySearch``.
#   func=TavilySearchResults(max_results=3).run,
# 🧠 Simple QA Tool Output:
#  In LangChain, LangGraph refers to a graph-based language model that represents the input text as a graph structure. This allows for more effective processing and analysis of complex linguistic relationships within the text.
#
# LangGraph uses a combination of techniques such as dependency parsing, named entity recognition, and coreference resolution to create a graph representation of the input text. This graph captures various aspects of the text's meaning, including:
#
# 1. **Dependency relationships**: The graph shows how words are related through dependencies like subject-verb-object relationships.
# 2. **Named entities**: LangGraph identifies specific entities mentioned in the text, such as people, organizations, and locations.
# 3. **Coreference chains**: The model resolves pronouns and other anaphoric references to their antecedents, creating a chain of connected mentions.
#
# By representing the input text as a graph, LangGraph enables more sophisticated natural language processing (NLP) tasks, such as:
#
# 1. **Question answering**: LangGraph can answer questions by traversing the graph structure to find relevant information.
# 2. **Text classification**: The model can classify texts based on their semantic meaning and relationships.
# 3. **Summarization**: LangGraph can generate summaries by identifying key entities and relationships in the original text.
#
# In summary, LangGraph is a powerful component of LangChain that enables more advanced NLP capabilities by representing input text as a graph structure, capturing complex linguistic relationships, and facilitating tasks like question answering, text classification, and summarization.
#
# 📝 Summarizer Tool Output:
#  Here is a summary of the text:
#
# LangGraph is a framework that enables the creation of complex, stateful AI agents using LangChain. It achieves this by employing a graph-based approach to represent an agent's workflow and memory.
#
# 🌐 Web Search Tool Output:
#  [{'title': 'GPT-5.6 Preview System Card - OpenAI Deployment Safety Hub', 'url': 'https://deploymentsafety.openai.com/gpt-5-6-preview', 'content': 'Published June 26, 2026\n\n# GPT-5.6 Preview System Card\n\n## 1. Introduction\n\nGPT-5.6 is a new family of three models: Sol, our new flagship model;\nTerra, a capable lower-cost option; and Luna, our fastest and most\ncost-efficient model. The safeguards we have built for this launch—our\nmost robust yet—are built to deliver these models safely and at scale,\naround the world. [...] ## 9.2 Research Category Update: Sandbagging\n\n## 9.2.1 External Evaluations - Apollo Research\n\nApollo Research is focused on reducing risks from dangerous\ncapabilities in advanced AI systems, especially scheming behaviors.\nApollo evaluated GPT-5.6 Sol for strategic deception, scheming, and\nsabotage, comparing it with GPT-5.5, GPT-5.4, GPT-5.3 Codex, and related\npre-release checkpoints. [...] ## 9.1.3 AI Self-Improvement Capabilities\n\nStarting with this launch, we’ve updated and expanded our\nself-improvement evaluations to better capture the kinds of realistic,\nend-to-end tasks that newer models can attempt, rather than older tasks.\nExisting measures were also becoming saturated (Monorepo-Bench) or upon\nreview contained some problems that were not solvable under test\nconditions and thus made overall results harder to interpret (OPQA). We\nbelieve this revised suite provides a richer and more grounded view of\nAI self-improvement capability.\n\nOverview of AI Self-Improvement evaluations\n\n### Table 13\n\nTable 13', 'score': 0.7089592}, {'title': 'New update + rumors on GPT-5.6 launch : r/codex - Reddit', 'url': 'https://www.reddit.com/r/codex/comments/1u4mlq2/new_update_rumors_on_gpt56_launch', 'content': "Still needs better taste and context awareness. If it's got that, there's probably a dramatic shift to OpenAI. If not, still need Claude to plan", 'score': 0.58237284}, {'title': 'Previewing GPT-5.6 Sol: a next-generation model | OpenAI', 'url': 'https://openai.com/index/previewing-gpt-5-6-sol', 'content': 'OpenAI previews GPT-5.6 Sol, a next-generation model with stronger capabilities in coding, science, and cybersecurity, paired with its most advanced safety', 'score': 0.55478466}]
