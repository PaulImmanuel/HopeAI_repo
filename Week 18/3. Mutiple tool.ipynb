# %%
import os
from dotenv import load_dotenv
from langchain_ollama import ChatOllama
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.agents import Tool


# 🔸 Initialize the LLM
llm = ChatOllama(model="llama3", temperature=0)
# ✅ Tool 1: Simple QA Tool
qa_prompt = PromptTemplate.from_template("Answer clearly: {question}")
qa_chain = LLMChain(llm=llm, prompt=qa_prompt)
qa_tool = Tool(
    name="Simple QA",
    func=qa_chain.run,
    description="Answer factual questions clearly"
)

# ✅ Tool 2: Summarizer Tool
summary_prompt = PromptTemplate.from_template("Summarize the following text:\n\n{text}")
summary_chain = LLMChain(llm=llm, prompt=summary_prompt)
summary_tool = Tool(
    name="Summarizer",
    func=summary_chain.run,
    description="Summarizes input text"
)

# 🔧 Tool usage examples
qa_query = "What is LangGraph in LangChain?"
summary_text = """
LangGraph is a library built on top of LangChain that helps developers create stateful, multi-step agents 
as graphs. Each node represents a step like calling an LLM or a tool. It's ideal for advanced AI workflows.
"""

# 🚀 Run tools manually
print("\n🧠 Simple QA Tool Output:\n", qa_tool.run({"question": qa_query}))
print("\n📝 Summarizer Tool Output:\n", summary_tool.run({"text": summary_text}))
# Out:
# C:\Users\Paul\AppData\Local\Temp\ipykernel_16996\2337416342.py:13: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   qa_chain = LLMChain(llm=llm, prompt=qa_prompt)
# 🧠 Simple QA Tool Output:
#  In LangChain, LangGraph refers to a graph-based language model that represents the input text as a graph structure. This allows for more effective processing and analysis of complex linguistic relationships within the text.
#
# LangGraph uses a combination of techniques from natural language processing (NLP) and graph theory to create a graph representation of the input text. This representation captures various aspects of the text, such as:
#
# 1. Token-level information: LangGraph includes nodes representing individual tokens (words or subwords) in the input text.
# 2. Edge relationships: The model defines edges between these nodes based on linguistic features like part-of-speech tags, dependencies, and semantic roles.
# 3. Graph structure: LangGraph uses a graph structure to represent the hierarchical organization of the input text, including sentence-level and document-level relationships.
#
# By representing the input text as a graph, LangGraph enables more sophisticated processing and analysis capabilities compared to traditional sequence-based models. This includes:
#
# 1. Better handling of complex linguistic structures
# 2. Improved ability to capture long-range dependencies
# 3. Enhanced support for multi-hop reasoning and inference
#
# In LangChain, LangGraph is used as a foundation for various language understanding and generation tasks, such as question answering, text classification, and language translation.
#
# 📝 Summarizer Tool Output:
#  Here is a summary of the text:
#
# LangGraph is a library that builds upon LangChain and enables developers to create complex, multi-step AI agents as graphs. Each node in the graph represents a specific step, such as interacting with a large language model or using a tool. This library is well-suited for advanced AI workflows.
