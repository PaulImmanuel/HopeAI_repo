# %%
import pickle
import warnings

warnings.filterwarnings("ignore")

loaded_model = pickle.load(
    open("pre-processed_input.sav","rb")
)

loaded_scx = pickle.load(
    open("pre-processed_input_scx.sav","rb")
)

# %%
test_input = loaded_scx.transform([[
    120000,   # R&D Spend
    110000,   # Administration
    300000,   # Marketing Spend
    0,        # State_Florida
    1         # State_New York
]])

# %%
result = loaded_model.predict(test_input)

print("Predicted Profit:",result)
# Out:
# Predicted Profit: [107984.97640498]
